# %% [markdown]
# # Spotify listening history

# %% [markdown]
# ## Data loading

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("spotify.json")

# %%
df
# Out:
#                           ts  ms_played conn_country  \
# 0       2016-12-11T19:08:05Z        117           DE
# 1       2021-04-18T15:10:17Z      87270           DE
# 2       2021-05-07T13:27:02Z     209200           DE
# 3       2017-03-29T19:11:55Z     157026           DE
# 4       2021-04-28T10:46:24Z     172630           DE
# ...                      ...        ...          ...
# 103940  2021-05-09T00:49:36Z      93923           DE
# 103941  2016-04-14T01:41:56Z     162453           DE
# 103942  2021-05-15T11:18:46Z       1440           DE
# 103943  2021-06-05T01:33:24Z     191240           DE
# 103944  2021-01-31T15:22:17Z        725           DE
#
#                   master_metadata_track_name  \
# 0                               Bless Us All
# 1       I Love You (But I Hate Your Friends)
# 2                                      Liebe
# 3                         The Imitation Game
# 4                                       Boys
# ...                                      ...
# ...

# %%
df.columns
# Out:
# Index(['ts', 'ms_played', 'conn_country', 'master_metadata_track_name',
#        'master_metadata_album_artist_name', 'master_metadata_album_album_name',
#        'spotify_track_uri', 'episode_name', 'episode_show_name',
#        'spotify_episode_uri', 'reason_start', 'reason_end', 'shuffle',
#        'skipped', 'offline', 'offline_timestamp', 'incognito_mode'],
#       dtype='object')

# %% [markdown]
# ### Filter songs played too briefly

# %%
sorted_df = df.sort_values(by='ms_played')
sorted_df.head()
# Out:
#                          ts  ms_played conn_country  \
# 55837  2015-12-13T00:15:21Z          0           DE
# 46727  2016-10-22T14:38:02Z          0           DE
# 46723  2021-08-15T21:35:26Z          0           DE
# 46695  2016-12-20T20:44:35Z          0           DE
# 46666  2017-09-04T10:25:38Z          0           DE
#
#                               master_metadata_track_name  \
# 55837                                              Hello
# 46727        Don't You Worry Child (feat. Shweta Subram)
# 46723                             Rumors (feat. Cardi B)
# 46695                                             Snakes
# 46666  Always Look On The Bright Side Of Life - Origi...
#
#       master_metadata_album_artist_name master_metadata_album_album_name  \
# 55837                             Adele                            Hello
# 46727                    The Piano Guys                          Wonders
# 46723                             Lizzo           Rumors (feat. Cardi B)
# ...

# %%
#only_songs = sorted_df[sorted_df['master_metadata_track_name']!=None]
#only_songs
type(sorted_df.loc[8153, 'master_metadata_track_name']) #got it

#how do i check if there are doubles?

# please dictate :-D

uniques = sorted_df['master_metadata_track_name'].unique() #like this?
uniques

sorted_df.dropna(subset=['master_metadata_track_name'])
sorted_df.dropna(subset=['master_metadata_track_name'])
# Out:
#                          ts  ms_played conn_country  \
# 55837  2015-12-13T00:15:21Z          0           DE
# 46727  2016-10-22T14:38:02Z          0           DE
# 46723  2021-08-15T21:35:26Z          0           DE
# 46695  2016-12-20T20:44:35Z          0           DE
# 46666  2017-09-04T10:25:38Z          0           DE
# ...                     ...        ...          ...
# 58223  2022-01-18T20:58:40Z    1872719           DE
# 46768  2021-08-27T14:22:57Z    1872771           DE
# 18867  2015-04-07T03:04:54Z    3554464           DE
# 99907  2015-10-02T05:09:51Z    4200585           DE
# 14832  2016-04-17T01:10:33Z    4440000           DE
#
#                               master_metadata_track_name  \
# 55837                                              Hello
# 46727        Don't You Worry Child (feat. Shweta Subram)
# 46723                             Rumors (feat. Cardi B)
# 46695                                             Snakes
# ...

# %%
#whats the function again?

len(uniques)
len(sorted_df)
# Out:
# 103945

# %% [markdown]
# ## Favorite songs

# %%
most_played = sorted_df[-5:]
most_played
# Out:
#                          ts  ms_played conn_country  \
# 28272  2021-05-20T23:14:38Z    7467154           DE
# 8153   2020-12-09T16:17:29Z    7776455           DE
# 79047  2021-07-27T20:22:42Z    8932844           DE
# 59452  2020-06-03T21:38:40Z    8936414           DE
# 19591  2021-10-04T18:40:26Z    9367341           DE
#
#       master_metadata_track_name master_metadata_album_artist_name  \
# 28272                       None                              None
# 8153                        None                              None
# 79047                       None                              None
# 59452                       None                              None
# 19591                       None                              None
#
#       master_metadata_album_album_name spotify_track_uri  \
# 28272                             None              None
# 8153                              None              None
# 79047                             None              None
# ...
